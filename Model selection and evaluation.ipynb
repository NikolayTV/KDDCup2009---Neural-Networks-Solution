# %%
from sklearn import metrics
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.ensemble import RandomForestClassifier
import pickle
import numpy as np

# %%
X = pickle.load( open( "data_prepared/X.pkl", "rb" ) )
X = X.tocsr()

Y_churn = pickle.load( open( "data_prepared/Y_churn.pkl", "rb" ) )
Y_appet = pickle.load( open( "data_prepared/Y_appet.pkl", "rb" ) )
Y_upsell = pickle.load( open( "data_prepared/Y_upsell.pkl", "rb" ) )

# %%
def gridSearch(X, y, predName):
    cv = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=0)
    results = np.empty([0, 3])

    for train_index, test_index in cv.split(X, y):
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        count = 0
        for n_estimators in range(50,550,50):
            for max_depth in range(1,16):
                print('count:', count)
                count += 1
                mdl = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,  n_jobs=8, class_weight='balanced')
                mdl.fit(X_train, y_train)
                
                pred = mdl.predict(X_test)
                auc = metrics.roc_auc_score(y_test,pred)
                
                output = np.array([n_estimators,max_depth, auc])
                results = np.vstack((results, output))
                print('n_estimators:', n_estimators, 'max_depth:', max_depth, 'auc:', auc)
                
    n_estimators = results[np.argmax(results[:,2]),0]
    max_depth = results[np.argmax(results[:,2]),1]
    auc = results[np.argmax(results[:,2]),2]
    return auc, int(n_estimators), int(max_depth)


def crossVal(X, y, predName, n_estimators, max_depth):
    cv = StratifiedShuffleSplit(n_splits=10, test_size=0.3, random_state=0)
    aucResults = []
    f1Results = []
    count = 0 
    
    for train_index, test_index in cv.split(X, y):
        print(count, 'CV split is going on ...')
        count += 1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        mdl = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,  n_jobs=8, class_weight='balanced')
        mdl.fit(X_train, y_train)
        
        pred = mdl.predict(X_test)
        auc = metrics.roc_auc_score(y_test,pred)
        f1 = metrics.f1_score(y_test,pred)
        
        aucResults.append(auc)
        f1Results.append(f1)

    return aucResults, f1Results

# %%
print('Training models...')
auc, n_estimators, max_depth = gridSearch(X, Y_churn, 'churn')

print('churn - best random forest model: AUC=',auc,
      'n_estimators=',n_estimators,'max_depth=',max_depth)

aucResults, f1Results = crossVal(X, Y_churn, 'churn', n_estimators, max_depth)

print('AUC mean=',np.mean(aucResults), 'std=',np.std(aucResults))
# Out:
# Training models...
# count: 0
# n_estimators: 50 max_depth: 1 auc: 0.610925655296
# count: 1
# n_estimators: 50 max_depth: 2 auc: 0.613219180609
# count: 2
# n_estimators: 50 max_depth: 3 auc: 0.625680947828
# count: 3
# n_estimators: 50 max_depth: 4 auc: 0.615981047688
# count: 4
# n_estimators: 50 max_depth: 5 auc: 0.621730292453
# count: 5
# n_estimators: 50 max_depth: 6 auc: 0.621049491826
# count: 6
# n_estimators: 50 max_depth: 7 auc: 0.621827346409
# count: 7
# n_estimators: 50 max_depth: 8 auc: 0.6275313026
# count: 8
# n_estimators: 50 max_depth: 9 auc: 0.62146994448
# count: 9
# n_estimators: 50 max_depth: 10 auc: 0.628162889315
# count: 10
# n_estimators: 50 max_depth: 11 auc: 0.622422329358
# count: 11
# n_estimators: 50 max_depth: 12 auc: 0.613932512467
# count: 12
# n_estimators: 50 max_depth: 13 auc: 0.601996544133
# count: 13
# n_estimators: 50 max_depth: 14 auc: 0.58797381761
# count: 14
# n_estimators: 50 max_depth: 15 auc: 0.576599368727
# count: 15
# n_estimators: 100 max_depth: 1 auc: 0.61945899436
# count: 16
# n_estimators: 100 max_depth: 2 auc: 0.619549964044
# count: 17
# n_estimators: 100 max_depth: 3 auc: 0.612903583519
# count: 18
# n_estimators: 100 max_depth: 4 auc: 0.621469993547
# count: 19
# n_estimators: 100 max_depth: 5 auc: 0.6249635925
# count: 20
# n_estimators: 100 max_depth: 6 auc: 0.626501441384
# count: 21
# n_estimators: 100 max_depth: 7 auc: 0.632402155088
# count: 22
# n_estimators: 100 max_depth: 8 auc: 0.628062351622
# count: 23
# n_estimators: 100 max_depth: 9 auc: 0.628051458812
# count: 24
# n_estimators: 100 max_depth: 10 auc: 0.616757970004
# count: 25
# n_estimators: 100 max_depth: 11 auc: 0.610436312978
# count: 26
# n_estimators: 100 max_depth: 12 auc: 0.606427758884
# count: 27
# n_estimators: 100 max_depth: 13 auc: 0.597863507791
# count: 28
# n_estimators: 100 max_depth: 14 auc: 0.585907078639
# count: 29
# n_estimators: 100 max_depth: 15 auc: 0.568654535805
# count: 30
# n_estimators: 150 max_depth: 1 auc: 0.613904740708
# count: 31
# n_estimators: 150 max_depth: 2 auc: 0.613925643127
# count: 32
# n_estimators: 150 max_depth: 3 auc: 0.610979187078
# count: 33
# n_estimators: 150 max_depth: 4 auc: 0.625326195501
# count: 34
# n_estimators: 150 max_depth: 5 auc: 0.63161213196
# count: 35
# n_estimators: 150 max_depth: 6 auc: 0.621894813138
# count: 36
# n_estimators: 150 max_depth: 7 auc: 0.627237932729
# count: 37
# n_estimators: 150 max_depth: 8 auc: 0.630057698528
# count: 38
# n_estimators: 150 max_depth: 9 auc: 0.629573213815
# count: 39
# n_estimators: 150 max_depth: 10 auc: 0.624770269655
# count: 40
# n_estimators: 150 max_depth: 11 auc: 0.615252308883
# count: 41
# n_estimators: 150 max_depth: 12 auc: 0.611679908791
# count: 42
# n_estimators: 150 max_depth: 13 auc: 0.599669506255
# count: 43
# n_estimators: 150 max_depth: 14 auc: 0.59390892708
# count: 44
# n_estimators: 150 max_depth: 15 auc: 0.57430932715
# count: 45
# n_estimators: 200 max_depth: 1 auc: 0.61220757221
# count: 46
# n_estimators: 200 max_depth: 2 auc: 0.629350843476
# count: 47
# n_estimators: 200 max_depth: 3 auc: 0.620462310485
# count: 48
# n_estimators: 200 max_depth: 4 auc: 0.62594428887
# count: 49
# n_estimators: 200 max_depth: 5 auc: 0.623339975003
# count: 50
# n_estimators: 200 max_depth: 6 auc: 0.631848044711
# count: 51
# n_estimators: 200 max_depth: 7 auc: 0.624576161743
# count: 52
# n_estimators: 200 max_depth: 8 auc: 0.62846499306
# count: 53
# n_estimators: 200 max_depth: 9 auc: 0.626509242991
# count: 54
# n_estimators: 200 max_depth: 10 auc: 0.617130141014
# count: 55
# n_estimators: 200 max_depth: 11 auc: 0.622256483872
# count: 56
# n_estimators: 200 max_depth: 12 auc: 0.612461247111
# count: 57
# n_estimators: 200 max_depth: 13 auc: 0.596084496018
# count: 58
# n_estimators: 200 max_depth: 14 auc: 0.586238328011
# count: 59
# n_estimators: 200 max_depth: 15 auc: 0.578012735363
# count: 60
# n_estimators: 250 max_depth: 1 auc: 0.610813783193
# count: 61
# n_estimators: 250 max_depth: 2 auc: 0.612220182355
# count: 62
# n_estimators: 250 max_depth: 3 auc: 0.61866632163
# count: 63
# n_estimators: 400 max_depth: 5 auc: 0.63105061251
# count: 110
# n_estimators: 400 max_depth: 6 auc: 0.63676590311
# count: 111
# n_estimators: 400 max_depth: 7 auc: 0.634708732148
# count: 112
# n_estimators: 400 max_depth: 8 auc: 0.623330799528
# count: 113
# n_estimators: 400 max_depth: 9 auc: 0.623174522051
# count: 114
# n_estimators: 400 max_depth: 10 auc: 0.620339496505
# count: 115
# n_estimators: 400 max_depth: 11 auc: 0.620473988362
# count: 116
# n_estimators: 400 max_depth: 12 auc: 0.615014629731
# count: 117
# n_estimators: 400 max_depth: 13 auc: 0.601783251137
# count: 118
# n_estimators: 400 max_depth: 14 auc: 0.586438127661
# count: 119
# n_estimators: 400 max_depth: 15 auc: 0.576392601603
# count: 120
# n_estimators: 450 max_depth: 1 auc: 0.605896366394
# count: 121
# n_estimators: 450 max_depth: 2 auc: 0.611300426841
# count: 122
# n_estimators: 450 max_depth: 3 auc: 0.622546026538
# count: 123
# n_estimators: 450 max_depth: 4 auc: 0.629039171723
# count: 124
# n_estimators: 450 max_depth: 5 auc: 0.633310183659
# count: 125
# n_estimators: 450 max_depth: 6 auc: 0.625013198945
# count: 126
# n_estimators: 450 max_depth: 7 auc: 0.62899996742
# count: 127
# n_estimators: 450 max_depth: 8 auc: 0.628099347923
# count: 128
# n_estimators: 450 max_depth: 9 auc: 0.625565542921
# count: 129
# n_estimators: 450 max_depth: 10 auc: 0.623299004299
# count: 130
# n_estimators: 450 max_depth: 11 auc: 0.620122278171
# count: 131
# n_estimators: 450 max_depth: 12 auc: 0.61163246128
# count: 132
# n_estimators: 450 max_depth: 13 auc: 0.601221731686
# count: 133
# n_estimators: 450 max_depth: 14 auc: 0.590310423497
# count: 134
# n_estimators: 450 max_depth: 15 auc: 0.571299329709
# count: 135
# n_estimators: 500 max_depth: 1 auc: 0.605418849154
# count: 136
# n_estimators: 500 max_depth: 2 auc: 0.617655596431
# count: 137
# n_estimators: 500 max_depth: 3 auc: 0.616539083402
# count: 138
# n_estimators: 500 max_depth: 4 auc: 0.62203803887
# count: 139
# n_estimators: 500 max_depth: 5 auc: 0.627340678424
# count: 140
# n_estimators: 500 max_depth: 6 auc: 0.628233005646
# count: 141
# n_estimators: 500 max_depth: 7 auc: 0.632480073027
# count: 142
# n_estimators: 500 max_depth: 8 auc: 0.629499662814
# count: 143
# n_estimators: 500 max_depth: 9 auc: 0.624405507719
# count: 144
# n_estimators: 500 max_depth: 10 auc: 0.622250399599
# count: 145
# n_estimators: 500 max_depth: 11 auc: 0.616689620074
# count: 146
# n_estimators: 500 max_depth: 12 auc: 0.615907398554
# count: 147
# n_estimators: 500 max_depth: 13 auc: 0.607065871472
# count: 148
# n_estimators: 500 max_depth: 14 auc: 0.587591195391
# count: 149
# n_estimators: 500 max_depth: 15 auc: 0.571958786317
# churn - best random forest model: AUC= 0.63676590311 n_estimators= 400 max_depth= 6
# 0 CV split is going on ...
# 1 CV split is going on ...
# 2 CV split is going on ...
# 3 CV split is going on ...
# 4 CV split is going on ...
# 5 CV split is going on ...
# 6 CV split is going on ...
# 7 CV split is going on ...
# 8 CV split is going on ...
# 9 CV split is going on ...
# AUC mean= 0.633500827461 std= 0.00373801942544
